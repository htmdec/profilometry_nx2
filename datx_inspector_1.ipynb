# %% [markdown]
# ## Inspecting .datx / HDF5 Files
# ### This notebook will:
# 1. Open an HDF5-based `.datx` file.
# 2. Recursively traverse all groups and datasets.
# 3. Collect and display for each object:
#     - Name and full path
#     - Type (Group or Dataset)
#     - Shape & dtype (for datasets)
#     - Attributes (as key→value dict)
# 4. Present the results in Python dict and tabular form.

# %%
# Dependencies
import h5py
import json
from pprint import pprint
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Define a recursive inspection function
# Walk the file and build a dictionary of metadata descriptors.

# %%
def inspect_hdf5(file_path):
    """
    Inspect an HDF5 file (.h5, .datx) and return a dict describing
    all groups and datasets, including attributes and dataset shapes/dtypes.
    """
    def _visit(name, obj, collector):
        entry = {
            'path': name,
            'type': 'Group' if isinstance(obj, h5py.Group) else 'Dataset',
            'attrs': dict(obj.attrs)
        }
        if isinstance(obj, h5py.Dataset):
            entry.update({
                'shape': obj.shape,
                'dtype': str(obj.dtype)
            })
        collector[name] = entry

    descriptors = {}
    with h5py.File(file_path, 'r') as f:
        f.visititems(lambda name, obj: _visit(name, obj, descriptors))
    return descriptors

# %% [markdown]
# ## 2. Load and inspect your `.datx` or `.h5` file
# Replace `'path/to/your/file.datx'` below with your actual filename.

# %%
# Example usage
file_name = '/Users/elbert/prysm_play/FS cuts/Middle.datx'  # ← update this path
metadata = inspect_hdf5(file_name)

print("### Full Metadata Descriptor Dict:")
pprint(metadata)
# Out:
# ### Full Metadata Descriptor Dict:
# {'Attributes': {'attrs': {'File Layout Version': array([1], dtype=int32)},
#                 'path': 'Attributes',
#                 'type': 'Group'},
#  'Attributes/System': {'attrs': {},
#                        'path': 'Attributes/System',
#                        'type': 'Group'},
#  'Attributes/{5CB51FA7-9361-4A66-AAB3-EE9EE1D96588}': {'attrs': {'Data Context.Data Attributes.AGC': array([0], dtype=uint8),
#                                                                  'Data Context.Data Attributes.AStopID': array(['Open'], dtype=object),
#                                                                  'Data Context.Data Attributes.AStopSize': array([((b'LinearCat', b'MilliMeters', array([0.])), 1.86)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.AStopSize:Unit': array(['MilliMeters'], dtype=object),
#                                                                  'Data Context.Data Attributes.AStopSize:Value': array([1.86]),
#                                                                  'Data Context.Data Attributes.Acquisition Type': array(['Normal'], dtype=object),
#                                                                  'Data Context.Data Attributes.Alignment Transform Unit': array(['NotSet'], dtype=object),
#                                                                  'Data Context.Data Attributes.Average Minimum Valid': array([((b'PercentCat', b'Percent', array([], dtype=float64)), 100.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Average Minimum Valid:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Average Minimum Valid:Value': array([100.]),
#                                                                  'Data Context.Data Attributes.Camera Height': array([((b'DimensionCat', b'Pixels', b'LateralCat', b'Pixels', array([0.00000000e+00, 8.61371347e-07, 0.00000000e+00, 0.00000000e+00])), 1000.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'SubCategory', 'SubUnit', 'Parameters'], 'formats': ['O', 'O', 'O', 'O', 'O'], 'offsets': [0, 8, 16, 24, 32], 'itemsize': 48}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Camera Height:Unit': array(['Pixels'], dtype=object),
#                                                                  'Data Context.Data Attributes.Camera Height:Value': array([1000.]),
#                                                                  'Data Context.Data Attributes.Camera Mode': array(['1000 x 1000 @ 195Hz'], dtype=object),
#                                                                  'Data Context.Data Attributes.Camera Width': array([((b'DimensionCat', b'Pixels', b'LateralCat', b'Pixels', array([0.00000000e+00, 8.61371347e-07, 0.00000000e+00, 0.00000000e+00])), 1000.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'SubCategory', 'SubUnit', 'Parameters'], 'formats': ['O', 'O', 'O', 'O', 'O'], 'offsets': [0, 8, 16, 24, 32], 'itemsize': 48}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Camera Width:Unit': array(['Pixels'], dtype=object),
#                                                                  'Data Context.Data Attributes.Camera Width:Value': array([1000.]),
#                                                                  'Data Context.Data Attributes.Data Stage Pitch': array([((b'MotorPositionCat', b'MicroRadians', array([182.85714286])), -5324.1125)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Data Stage Pitch:Unit': array(['MicroRadians'], dtype=object),
#                                                                  'Data Context.Data Attributes.Data Stage Pitch:Value': array([-5324.1125]),
#                                                                  'Data Context.Data Attributes.Data Stage Roll': array([((b'MotorPositionCat', b'MicroRadians', array([182.85714286])), -3327.165625)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Data Stage Roll:Unit': array(['MicroRadians'], dtype=object),
#                                                                  'Data Context.Data Attributes.Data Stage Roll:Value': array([-3327.165625]),
#                                                                  'Data Context.Data Attributes.Data Stage Theta': array([((b'FixedUnitCat', b'NotSet', array([], dtype=float64)), nan)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Data Stage Theta:Value': array([nan]),
#                                                                  'Data Context.Data Attributes.Data Stage X': array([((b'MotorPositionCat', b'MilliMeters', array([10000.])), -11.3022)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Data Stage X:Unit': array(['MilliMeters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Data Stage X:Value': array([-11.3022]),
#                                                                  'Data Context.Data Attributes.Data Stage Y': array([((b'MotorPositionCat', b'MilliMeters', array([10000.])), -13.0439)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Data Stage Y:Unit': array(['MilliMeters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Data Stage Y:Value': array([-13.0439]),
#                                                                  'Data Context.Data Attributes.Data Stage Z': array([((b'MotorPositionCat', b'MilliMeters', array([204800.])), 9.76834473)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Data Stage Z:Unit': array(['MilliMeters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Data Stage Z:Value': array([9.76834473]),
#                                                                  'Data Context.Data Attributes.Discriminator Size': array([64], dtype=int32),
#                                                                  'Data Context.Data Attributes.Enable Stitch': array([0], dtype=uint8),
#                                                                  'Data Context.Data Attributes.Enable Zip Scan': array([0], dtype=uint8),
#                                                                  'Data Context.Data Attributes.FDA Noise Threshold': array([((b'PercentCat', b'Percent', array([], dtype=float64)), 4.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.FDA Noise Threshold:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.FDA Noise Threshold:Value': array([4.]),
#                                                                  'Data Context.Data Attributes.FDA Signal Threshold': array([((b'PercentCat', b'Percent', array([], dtype=float64)), 4.85)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.FDA Signal Threshold:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.FDA Signal Threshold:Value': array([4.85]),
#                                                                  'Data Context.Data Attributes.FStopID': array(['Max Open'], dtype=object),
#                                                                  'Data Context.Data Attributes.FStopSize': array([((b'LinearCat', b'MilliMeters', array([0.])), 11.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.FStopSize:Unit': array(['MilliMeters'], dtype=object),
#                                                                  'Data Context.Data Attributes.FStopSize:Value': array([11.]),
#                                                                  'Data Context.Data Attributes.Fiducial Editor.Fiducial Set 1.Fiducial Count': array([0], dtype=int32),
#                                                                  'Data Context.Data Attributes.Fiducial Editor.Fiducial Set Count': array([1], dtype=int32),
#                                                                  'Data Context.Data Attributes.Fiducial Time Stamp': array([(1712692799, 881, -240, 0)],
#       dtype=[('time', '<i8'), ('millitm', '<u2'), ('timezone', '<i2'), ('dstflag', '<i2')]),
#                                                                  'Data Context.Data Attributes.Field Flattening': array([0], dtype=uint8),
#                                                                  'Data Context.Data Attributes.Field Flattening Applied': array([0], dtype=uint8),
#                                                                  'Data Context.Data Attributes.Films Interface Threshold': array([((b'PercentCat', b'Percent', array([], dtype=float64)), 1.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Films Interface Threshold:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Films Interface Threshold:Value': array([1.]),
#                                                                  'Data Context.Data Attributes.FilterID': array(['Open'], dtype=object),
#                                                                  'Data Context.Data Attributes.Frame Count': array([48], dtype=int32),
#                                                                  'Data Context.Data Attributes.Fringe Order Analysis': array(['Advanced'], dtype=object),
#                                                                  'Data Context.Data Attributes.Fringe Removal': array(['Modulation'], dtype=object),
#                                                                  'Data Context.Data Attributes.Fringe Removal On': array([1], dtype=uint8),
#                                                                  'Data Context.Data Attributes.Instrument': array(['NewView'], dtype=object),
#                                                                  'Data Context.Data Attributes.Intensity Location Percent': array([((b'PercentCat', b'Percent', array([], dtype=float64)), 0.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Intensity Location Percent:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Intensity Location Percent:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Light Level': array([((b'PercentCat', b'Percent', array([], dtype=float64)), 1.70901048)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Light Level:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Light Level:Value': array([1.70901048]),
#                                                                  'Data Context.Data Attributes.Max Intensity': array([255], dtype=int32),
#                                                                  'Data Context.Data Attributes.Measurement ID': array([0], dtype=int32),
#                                                                  'Data Context.Data Attributes.Measurement Mode': array(['CSI'], dtype=object),
#                                                                  'Data Context.Data Attributes.Measurement Type': array(['Surface'], dtype=object),
#                                                                  'Data Context.Data Attributes.Modulation Threshold': array([((b'PercentCat', b'Percent', array([], dtype=float64)), 15.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Modulation Threshold:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Modulation Threshold:Value': array([15.]),
#                                                                  'Data Context.Data Attributes.Numerical Aperture': array([((b'NoUnitsCat', b'NoUnits', array([], dtype=float64)), 0.3)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Numerical Aperture:Value': array([0.3]),
#                                                                  'Data Context.Data Attributes.ObjectiveID': array(['10X Mirau'], dtype=object),
#                                                                  'Data Context.Data Attributes.ObjectiveNA': array([((b'NoUnitsCat', b'NoUnits', array([], dtype=float64)), 0.3)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.ObjectiveNA:Value': array([0.3]),
#                                                                  'Data Context.Data Attributes.Obliquity': array([((b'FixedUnitCat', b'NotSet', array([], dtype=float64)), 1.02993)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Obliquity Correction': array([((b'FixedUnitCat', b'NotSet', array([], dtype=float64)), 1.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Obliquity Correction:Value': array([1.]),
#                                                                  'Data Context.Data Attributes.Obliquity:Value': array([1.02993]),
#                                                                  'Data Context.Data Attributes.Phase Averages': array([1], dtype=int32),
#                                                                  'Data Context.Data Attributes.Refraction Index': array([((b'FixedUnitCat', b'NotSet', array([], dtype=float64)), 1.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Refraction Index:Value': array([1.]),
#                                                                  'Data Context.Data Attributes.Scan Device': array(['PZT'], dtype=object),
#                                                                  'Data Context.Data Attributes.Scan Direction': array(['Downward'], dtype=object),
#                                                                  'Data Context.Data Attributes.Scan Increment': array([((b'LinearCat', b'Meters', array([0.])), 7.12067951e-08)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Scan Increment:Unit': array(['Meters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Scan Increment:Value': array([7.12067951e-08]),
#                                                                  'Data Context.Data Attributes.Scan Length': array(['20 um'], dtype=object),
#                                                                  'Data Context.Data Attributes.Scan Origin': array(['Center'], dtype=object),
#                                                                  'Data Context.Data Attributes.Scan Rate': array(['1X'], dtype=object),
#                                                                  'Data Context.Data Attributes.Shutter Speed': array([((b'PercentCat', b'Percent', array([], dtype=float64)), 100.)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Shutter Speed:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Shutter Speed:Value': array([100.]),
#                                                                  'Data Context.Data Attributes.Software Info Name': array(['Mx'], dtype=object),
#                                                                  'Data Context.Data Attributes.Software Info Version': array(['9.1.0.27'], dtype=object),
#                                                                  'Data Context.Data Attributes.Source Mode': array(['Mono-Yellow'], dtype=object),
#                                                                  'Data Context.Data Attributes.Stage Pitch': array([((b'MotorPositionCat', b'MicroRadians', array([182.85714286])), -5324.1125)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Stage Pitch:Unit': array(['MicroRadians'], dtype=object),
#                                                                  'Data Context.Data Attributes.Stage Pitch:Value': array([-5324.1125]),
#                                                                  'Data Context.Data Attributes.Stage Roll': array([((b'MotorPositionCat', b'MicroRadians', array([182.85714286])), -3327.165625)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Stage Roll:Unit': array(['MicroRadians'], dtype=object),
#                                                                  'Data Context.Data Attributes.Stage Roll:Value': array([-3327.165625]),
#                                                                  'Data Context.Data Attributes.Stage X': array([((b'MotorPositionCat', b'MilliMeters', array([10000.])), -11.3022)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Stage X:Unit': array(['MilliMeters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Stage X:Value': array([-11.3022]),
#                                                                  'Data Context.Data Attributes.Stage Y': array([((b'MotorPositionCat', b'MilliMeters', array([10000.])), -13.0439)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Stage Y:Unit': array(['MilliMeters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Stage Y:Value': array([-13.0439]),
#                                                                  'Data Context.Data Attributes.Stage Z': array([((b'MotorPositionCat', b'MilliMeters', array([204800.])), 9.76834473)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Stage Z:Unit': array(['MilliMeters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Stage Z:Value': array([9.76834473]),
#                                                                  'Data Context.Data Attributes.Subtract System Error': array([0], dtype=uint8),
#                                                                  'Data Context.Data Attributes.Swli Averages': array([1], dtype=int32),
#                                                                  'Data Context.Data Attributes.System Error Applied': array([0], dtype=uint8),
#                                                                  'Data Context.Data Attributes.System Magnification': array([((b'FixedUnitCat', b'NotSet', array([], dtype=float64)), 10.07867455)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.System Magnification:Value': array([10.07867455]),
#                                                                  'Data Context.Data Attributes.System Serial Number': array(['23-18-88196'], dtype=object),
#                                                                  'Data Context.Data Attributes.System Type': array(['Nexview NX2'], dtype=object),
#                                                                  'Data Context.Data Attributes.TextCount': array([20], dtype=int32),
#                                                                  'Data Context.Data Attributes.Time Stamp': array([(1712692603, 0, -240, 0)],
#       dtype=[('time', '<i8'), ('millitm', '<u2'), ('timezone', '<i2'), ('dstflag', '<i2')]),
#                                                                  'Data Context.Data Attributes.Use All Bins': array([0], dtype=uint8),
#                                                                  'Data Context.Data Attributes.Use Optical Coordinates': array([0], dtype=uint8),
#                                                                  'Data Context.Data Attributes.Use Reference Plane': array([0], dtype=uint8),
#                                                                  'Data Context.Data Attributes.Wavelength': array([((b'LinearCat', b'Meters', array([0.])), 6.10811959e-07)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Data Attributes.Wavelength:Unit': array(['Meters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Wavelength:Value': array([6.10811959e-07]),
#                                                                  'Data Context.Data Attributes.Z Resolution': array(['High'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Light Level 1:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Light Level 1:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zip Scan Light Level 2:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Light Level 2:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zip Scan Light Level 3:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Light Level 3:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zip Scan Light Level 4:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Light Level 4:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zip Scan Shutter 1:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Shutter 1:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zip Scan Shutter 2:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Shutter 2:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zip Scan Shutter 3:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Shutter 3:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zip Scan Shutter 4:Unit': array(['Percent'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Shutter 4:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zip Scan Skip Length 1:Unit': array(['Meters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Skip Length 1:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zip Scan Skip Length 2:Unit': array(['Meters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Skip Length 2:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zip Scan Skip Length 3:Unit': array(['Meters'], dtype=object),
#                                                                  'Data Context.Data Attributes.Zip Scan Skip Length 3:Value': array([0.]),
#                                                                  'Data Context.Data Attributes.Zoom': array(['1.0X'], dtype=object),
#                                                                  'Data Context.Lateral Resolution': array([((b'LinearCat', b'Meters', array([0.])), 8.61371347e-07)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Data Context.Lateral Resolution:Unit': array(['Meters'], dtype=object),
#                                                                  'Data Context.Lateral Resolution:Value': array([8.61371347e-07]),
#                                                                  'Data Context.Window': array([(0, 0, 1000, 1000)],
#       dtype=[('RowStart', '<i4'), ('ColumnStart', '<i4'), ('Width', '<i4'), ('Height', '<i4')]),
#                                                                  'Group Number': array([1], dtype=int32),
#                                                                  'Intensity Data Context.Lateral Resolution': array([((b'LinearCat', b'Meters', array([0.])), 8.61371347e-07)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Intensity Data Context.Lateral Resolution:Unit': array(['Meters'], dtype=object),
#                                                                  'Intensity Data Context.Lateral Resolution:Value': array([8.61371347e-07]),
#                                                                  'Intensity Data Context.Window': array([(0, 0, 1000, 1000)],
#       dtype=[('RowStart', '<i4'), ('ColumnStart', '<i4'), ('Width', '<i4'), ('Height', '<i4')]),
#                                                                  'Property Bag List': array(['Data Context.Data Attributes\n'], dtype=object),
#                                                                  'Quality Data Context.Lateral Resolution': array([((b'LinearCat', b'Meters', array([0.])), 8.61371347e-07)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Quality Data Context.Lateral Resolution:Unit': array(['Meters'], dtype=object),
#                                                                  'Quality Data Context.Lateral Resolution:Value': array([8.61371347e-07]),
#                                                                  'Quality Data Context.Window': array([(0, 0, 1000, 1000)],
#       dtype=[('RowStart', '<i4'), ('ColumnStart', '<i4'), ('Width', '<i4'), ('Height', '<i4')]),
#                                                                  'Saturation Counts Data Context.Lateral Resolution': array([((b'LinearCat', b'Meters', array([0.])), 8.61371347e-07)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Saturation Counts Data Context.Lateral Resolution:Unit': array(['Meters'], dtype=object),
#                                                                  'Saturation Counts Data Context.Lateral Resolution:Value': array([8.61371347e-07]),
#                                                                  'Saturation Counts Data Context.Window': array([(0, 0, 1000, 1000)],
#       dtype=[('RowStart', '<i4'), ('ColumnStart', '<i4'), ('Width', '<i4'), ('Height', '<i4')]),
#                                                                  'Surface Data Context.Lateral Resolution': array([((b'LinearCat', b'Meters', array([0.])), 8.61371347e-07)],
#       dtype=[('Converter', {'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32}), ('Value', '<f8')]),
#                                                                  'Surface Data Context.Lateral Resolution:Unit': array(['Meters'], dtype=object),
#                                                                  'Surface Data Context.Lateral Resolution:Value': array([8.61371347e-07]),
#                                                                  'Surface Data Context.Window': array([(0, 0, 1000, 1000)],
#       dtype=[('RowStart', '<i4'), ('ColumnStart', '<i4'), ('Width', '<i4'), ('Height', '<i4')])},
#                                                        'path': 'Attributes/{5CB51FA7-9361-4A66-AAB3-EE9EE1D96588}',
#                                                        'type': 'Group'},
#  'Data': {'attrs': {}, 'path': 'Data', 'type': 'Group'},
#  'Data/Intensity': {'attrs': {}, 'path': 'Data/Intensity', 'type': 'Group'},
#  'Data/Intensity/{26EB0B6C-1F64-4AB9-BE85-C007079144B5}': {'attrs': {'Coordinates': array([(0, 0, 1000, 1000)],
#       dtype=[('RowStart', '<i4'), ('ColumnStart', '<i4'), ('Width', '<i4'), ('Height', '<i4')]),
#                                                                      'Group Number': array([1], dtype=int32),
#                                                                      'No Data': array([2147483647], dtype=int32),
#                                                                      'Unit': array(['Counts'], dtype=object),
#                                                                      'X Converter': array([(b'LateralCat', b'Pixels', b'LinearCat', b'Meters', array([0.00000000e+00, 8.61371347e-07, 0.00000000e+00, 0.00000000e+00]))],
#       dtype={'names': ['Category', 'BaseUnit', 'SubCategory', 'SubUnit', 'Parameters'], 'formats': ['O', 'O', 'O', 'O', 'O'], 'offsets': [0, 8, 16, 24, 32], 'itemsize': 48}),
#                                                                      'Y Converter': array([(b'LateralCat', b'Pixels', b'LinearCat', b'Meters', array([0.00000000e+00, 8.61371347e-07, 0.00000000e+00, 0.00000000e+00]))],
#       dtype={'names': ['Category', 'BaseUnit', 'SubCategory', 'SubUnit', 'Parameters'], 'formats': ['O', 'O', 'O', 'O', 'O'], 'offsets': [0, 8, 16, 24, 32], 'itemsize': 48}),
#                                                                      'Z Converter': array([(b'CountsCat', b'Counts', array([], dtype=float64))],
#       dtype={'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32})},
#                                                            'dtype': 'int32',
#                                                            'path': 'Data/Intensity/{26EB0B6C-1F64-4AB9-BE85-C007079144B5}',
#                                                            'shape': (1000,
#                                                                      1000),
#                                                            'type': 'Dataset'},
#  'Data/Quality': {'attrs': {}, 'path': 'Data/Quality', 'type': 'Group'},
#  'Data/Quality/{D7DB3063-CC29-45D6-AE08-38703E184D38}': {'attrs': {'Coordinates': array([(0, 0, 1000, 1000)],
#       dtype=[('RowStart', '<i4'), ('ColumnStart', '<i4'), ('Width', '<i4'), ('Height', '<i4')]),
#                                                                    'Group Number': array([1], dtype=int32),
#                                                                    'No Data': array([1.79769313e+308]),
#                                                                    'Unit': array(['NoUnits'], dtype=object),
#                                                                    'X Converter': array([(b'LateralCat', b'Pixels', b'LinearCat', b'Meters', array([0.00000000e+00, 8.61371347e-07, 0.00000000e+00, 0.00000000e+00]))],
#       dtype={'names': ['Category', 'BaseUnit', 'SubCategory', 'SubUnit', 'Parameters'], 'formats': ['O', 'O', 'O', 'O', 'O'], 'offsets': [0, 8, 16, 24, 32], 'itemsize': 48}),
#                                                                    'Y Converter': array([(b'LateralCat', b'Pixels', b'LinearCat', b'Meters', array([0.00000000e+00, 8.61371347e-07, 0.00000000e+00, 0.00000000e+00]))],
#       dtype={'names': ['Category', 'BaseUnit', 'SubCategory', 'SubUnit', 'Parameters'], 'formats': ['O', 'O', 'O', 'O', 'O'], 'offsets': [0, 8, 16, 24, 32], 'itemsize': 48}),
#                                                                    'Z Converter': array([(b'NoUnitsCat', b'NoUnits', array([], dtype=float64))],
#       dtype={'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32})},
#                                                          'dtype': 'float64',
#                                                          'path': 'Data/Quality/{D7DB3063-CC29-45D6-AE08-38703E184D38}',
#                                                          'shape': (1000, 1000),
#                                                          'type': 'Dataset'},
#  'Data/Saturation Counts': {'attrs': {},
#                             'path': 'Data/Saturation Counts',
#                             'type': 'Group'},
#  'Data/Saturation Counts/{0F6F4648-2693-46FA-8BB2-894616AEBA82}': {'attrs': {'Coordinates': array([(0, 0, 1000, 1000)],
#       dtype=[('RowStart', '<i4'), ('ColumnStart', '<i4'), ('Width', '<i4'), ('Height', '<i4')]),
#                                                                              'Group Number': array([1], dtype=int32),
#                                                                              'No Data': array([2147483647], dtype=int32),
#                                                                              'Unit': array(['NoUnits'], dtype=object),
#                                                                              'X Converter': array([(b'LateralCat', b'Pixels', b'LinearCat', b'Meters', array([0.00000000e+00, 8.61371347e-07, 0.00000000e+00, 0.00000000e+00]))],
#       dtype={'names': ['Category', 'BaseUnit', 'SubCategory', 'SubUnit', 'Parameters'], 'formats': ['O', 'O', 'O', 'O', 'O'], 'offsets': [0, 8, 16, 24, 32], 'itemsize': 48}),
#                                                                              'Y Converter': array([(b'LateralCat', b'Pixels', b'LinearCat', b'Meters', array([0.00000000e+00, 8.61371347e-07, 0.00000000e+00, 0.00000000e+00]))],
#       dtype={'names': ['Category', 'BaseUnit', 'SubCategory', 'SubUnit', 'Parameters'], 'formats': ['O', 'O', 'O', 'O', 'O'], 'offsets': [0, 8, 16, 24, 32], 'itemsize': 48}),
#                                                                              'Z Converter': array([(b'NoUnitsCat', b'NoUnits', array([], dtype=float64))],
#       dtype={'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32})},
#                                                                    'dtype': 'int32',
#                                                                    'path': 'Data/Saturation '
#                                                                            'Counts/{0F6F4648-2693-46FA-8BB2-894616AEBA82}',
#                                                                    'shape': (1000,
#                                                                              1000),
#                                                                    'type': 'Dataset'},
#  'Data/Surface': {'attrs': {}, 'path': 'Data/Surface', 'type': 'Group'},
#  'Data/Surface/{86FCB133-E4C2-4B29-8094-A086AA5A3DEF}': {'attrs': {'Coordinates': array([(0, 0, 1000, 1000)],
#       dtype=[('RowStart', '<i4'), ('ColumnStart', '<i4'), ('Width', '<i4'), ('Height', '<i4')]),
#                                                                    'Group Number': array([1], dtype=int32),
#                                                                    'Interferometric Scale Factor': array([0.5]),
#                                                                    'No Data': array([1.79769313e+308]),
#                                                                    'Obliquity Factor': array([1.]),
#                                                                    'Unit': array(['NanoMeters'], dtype=object),
#                                                                    'Wavelength': array([6.10811959e-07]),
#                                                                    'X Converter': array([(b'LateralCat', b'Pixels', b'LinearCat', b'Meters', array([0.00000000e+00, 8.61371347e-07, 0.00000000e+00, 0.00000000e+00]))],
#       dtype={'names': ['Category', 'BaseUnit', 'SubCategory', 'SubUnit', 'Parameters'], 'formats': ['O', 'O', 'O', 'O', 'O'], 'offsets': [0, 8, 16, 24, 32], 'itemsize': 48}),
#                                                                    'Y Converter': array([(b'LateralCat', b'Pixels', b'LinearCat', b'Meters', array([0.00000000e+00, 8.61371347e-07, 0.00000000e+00, 0.00000000e+00]))],
#       dtype={'names': ['Category', 'BaseUnit', 'SubCategory', 'SubUnit', 'Parameters'], 'formats': ['O', 'O', 'O', 'O', 'O'], 'offsets': [0, 8, 16, 24, 32], 'itemsize': 48}),
#                                                                    'Z Converter': array([(b'HeightCat', b'NanoMeters', array([0.00000000e+00, 6.10811959e-07, 5.00000000e-01, 1.00000000e+00]))],
#       dtype={'names': ['Category', 'BaseUnit', 'Parameters'], 'formats': ['O', 'O', 'O'], 'offsets': [0, 8, 16], 'itemsize': 32})},
#                                                          'dtype': 'float64',
#                                                          'path': 'Data/Surface/{86FCB133-E4C2-4B29-8094-A086AA5A3DEF}',
#                                                          'shape': (1000, 1000),
#                                                          'type': 'Dataset'},
#  'Data/{3AD5CF24-EE4A-49B2-B550-DAEF948C76A6}': {'attrs': {},
#                                                  'dtype': 'uint8',
#                                                  'path': 'Data/{3AD5CF24-EE4A-49B2-B550-DAEF948C76A6}',
#                                                  'shape': (1024,),
#                                                  'type': 'Dataset'},
#  'Data/{CF16554A-2933-469B-A8BF-CEB3B19FF82C}': {'attrs': {},
#                                                  'dtype': 'uint8',
#                                                  'path': 'Data/{CF16554A-2933-469B-A8BF-CEB3B19FF82C}',
#                                                  'shape': (5120,),
#                                                  'type': 'Dataset'},
#  'Measurement': {'attrs': {}, 'path': 'Measurement', 'type': 'Group'},
#  'MetaData': {'attrs': {},
#               'dtype': "[('Source', 'O'), ('Link', 'O'), ('Destination', 'O')]",
#               'path': 'MetaData',
#               'shape': (22,),
#               'type': 'Dataset'}}

# %% [markdown]
# ## 3. Convert to Pandas DataFrame for Tabular View
# Create a table summarizing each object in the file.

# %%
# Helper to make attribute values JSON-serializable
def serialize_attr(value):
    # Recursively handle numpy arrays, lists, tuples, scalars, and bytes
    if isinstance(value, np.ndarray):
        return serialize_attr(value.tolist())
    elif isinstance(value, (list, tuple)):
        return [serialize_attr(v) for v in value]
    elif isinstance(value, (np.generic,)):
        return value.item()
    elif isinstance(value, bytes):
        return value.decode(errors='ignore')
    else:
        return value

# Build DataFrame rows
rows = []
for path, info in metadata.items():
    attrs_raw = info.get('attrs', {})
    attrs_serial = {k: serialize_attr(v) for k, v in attrs_raw.items()}
    rows.append({
        'Path': path,
        'Type': info['type'],
        'Shape': info.get('shape', ''),
        'Dtype': info.get('dtype', ''),
        'Attrs': json.dumps(attrs_serial, ensure_ascii=False)
    })

# Create DataFrame
df = pd.DataFrame(rows)

df
# Out:
#                                                  Path     Type         Shape  \
# 0                                          Attributes    Group
# 1                                   Attributes/System    Group
# 2   Attributes/{5CB51FA7-9361-4A66-AAB3-EE9EE1D96588}    Group
# 3                                                Data    Group
# 4                                      Data/Intensity    Group
# 5   Data/Intensity/{26EB0B6C-1F64-4AB9-BE85-C00707...  Dataset  (1000, 1000)
# 6                                        Data/Quality    Group
# 7   Data/Quality/{D7DB3063-CC29-45D6-AE08-38703E18...  Dataset  (1000, 1000)
# 8                              Data/Saturation Counts    Group
# 9   Data/Saturation Counts/{0F6F4648-2693-46FA-8BB...  Dataset  (1000, 1000)
# 10                                       Data/Surface    Group
# 11  Data/Surface/{86FCB133-E4C2-4B29-8094-A086AA5A...  Dataset  (1000, 1000)
# 12        Data/{3AD5CF24-EE4A-49B2-B550-DAEF948C76A6}  Dataset       (1024,)
# 13        Data/{CF16554A-2933-469B-A8BF-CEB3B19FF82C}  Dataset       (5120,)
# 14                                        Measurement    Group
# 15                                           MetaData  Dataset         (22,)
#
#                                                 Dtype  \
# 0
# 1
# 2
# 3
# 4
# 5                                               int32
# 6
# 7                                             float64
# 8
# 9                                               int32
# 10
# 11                                            float64
# 12                                              uint8
# 13                                              uint8
# 14
# 15  [('Source', 'O'), ('Link', 'O'), ('Destination...
#
#                                                 Attrs
# 0                        {"File Layout Version": [1]}
# 1                                                  {}
# 2   {"Data Context.Data Attributes.AGC": [0], "Dat...
# 3                                                  {}
# 4                                                  {}
# 5   {"Coordinates": [[0, 0, 1000, 1000]], "Group N...
# 6                                                  {}
# 7   {"Coordinates": [[0, 0, 1000, 1000]], "Group N...
# 8                                                  {}
# 9   {"Coordinates": [[0, 0, 1000, 1000]], "Group N...
# 10                                                 {}
# 11  {"Coordinates": [[0, 0, 1000, 1000]], "Group N...
# 12                                                 {}
# 13                                                 {}
# 14                                                 {}
# 15                                                 {}
