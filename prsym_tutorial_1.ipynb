# %%
from prysm.interferogram import Interferogram
from prysm.sample_data import sample_files
# Out:
# /Users/elbert/miniconda3/envs/profilometry/lib/python3.13/site-packages/prysm/__init__.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution

# %%
path = sample_files('dat')
path
# Out:
# PosixPath('/Users/elbert/miniconda3/envs/profilometry/lib/python3.13/site-packages/prysm/../prysm-sampledata/valid_zygo_dat_file.dat')

# %%
interf = Interferogram.from_zygo_dat(path)

# %%
interf.plot2d()
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: >)

# %%
from prysm.geometry import circle

interf.recenter()
interf.mask(circle(12, interf.r))
interf.plot2d()
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: >)

# %%
interf.crop()
interf.plot2d(interpolation='bilinear')
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: >)

# %%
interf.recenter()
interf.remove_piston()
interf.remove_tiptilt()
interf.remove_power()
interf.plot2d(interpolation='bilinear')
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: >)

# %%
interf.pv, interf.rms # units are nm
# Out:
# (np.float64(76.20195082847323), np.float64(25.752977722290815))

# %%
w = interf.wavelength * 1e3 # wavelength is in microns
w/interf.pv, interf.rms
# Out:
# (np.float64(8.304249096302458), np.float64(25.752977722290815))
